# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from getdata import GetData
from predict import Predict
import plotly.express as px
import seaborn as sns
sns.set_theme()

# %%
data = GetData('data/winequality-red.csv', 'data/winequality-white.csv')

reds = Predict(data.reds)
whites = Predict(data.whites)
both = Predict(data.all)

# %%
qual = data.all.sort_values(by=['quality'])

sns.histplot(qual['quality'], kde=False, bins=range(1, 11))
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.title('Distribution of Wine Quality')
plt.show()

# %% [markdown]
# ## Prediction Evaluations
#
# 1. Random Forest Regression

# %%
reds.RanForReg()
# Out:
# Mean squared error:  0.30123812499999997
# R-squared:  0.5390429623873638

# %% [markdown]
# 2. Random Forest Regression Normalized

# %%
reds.RanForRegNorm()
# Out:
# Mean squared error:  0.34323075
# R-squared:  0.43842562198975377

# %% [markdown]
# 3. Ridge Regression

# %%
reds.RidgeReg()
# Out:
# Mean squared error:  0.3929488678812799
# R-squared:  0.3987064350775855

# %% [markdown]
# 4. Linear Regression

# %%
reds.LinReg()
# Out:
# Mean squared error:  0.390025143963954
# R-squared:  0.4031803412796233

# %% [markdown]
# 5. Lasso Regression

# %%
reds.LassoReg()
# Out:
# Mean squared error:  0.6476147191182037
# R-squared:  0.009014670905063582
